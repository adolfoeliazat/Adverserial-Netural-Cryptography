# %%
# batch_size = 512
# msg_len = 12 bits
# key_len = 12 bits
# comm_len = 12 bits

# No.of Adversarial runs = 60
# No. of iterations in each run = 2000
# Learning rate = 0.01

# %run adversarial_neural_cryptography.py
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5105)
# /home/icarus/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# training bob and alice, run: 1
# training loss: 0.996735334396
# training loss: 0.0305435936898
# training loss: 0.00993860233575
# training eve, run: 1
# training loss: 1.00667953491
# training loss: 0.0389935784042
# training loss: 0.0135105419904
# training bob and alice, run: 2
# training loss: 0.992466688156
# training eve, run: 2
# training loss: 0.995428085327
# training loss: 0.16872137785
# training loss: 0.173636823893
# training loss: 0.0845044255257
# training loss: 0.0928113758564
# training loss: 0.0854190140963
# training loss: 0.0882984697819
# training loss: 0.085207477212
# ...

# %%
# batch_size = 512
# msg_len = 12 bits
# key_len = 12 bits
# comm_len = 12 bits

# No.of Adversarial runs = 60
# No. of iterations in each run = 2000
# Learning rate = 0.001

# %run adversarial_neural_cryptography.py
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5105)
# /home/icarus/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# training bob and alice, run: 1
# training loss: 1.00119161606
# training loss: 0.440596848726
# training loss: 0.0341774299741
# training eve, run: 1
# training loss: 1.00006592274
# training loss: 0.26793140173
# training loss: 0.0317651331425
# training loss: 0.0157153829932
# training loss: 0.0100087765604
# training loss: 0.0106361955404
# training bob and alice, run: 2
# training loss: 0.986425101757
# training loss: 0.145093157887
# training loss: 0.130614504218
# training loss: 0.127183049917
# training loss: 0.126824244857
# training loss: 0.122185476124
# training loss: 0.129366785288
# ...

# %%
# batch_size = 512
# msg_len = 16 bits
# key_len = 16 bits
# comm_len = 16 bits

# No.of Adversarial runs = 60
# No. of iterations in each run = 2000
# Learning rate = 0.001

# %run adversarial_neural_cryptography.py
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5105)
# /home/icarus/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# training bob and alice, run: 1
# training loss: 0.998106479645
# training loss: 0.433558791876
# training loss: 0.0391591824591
# training loss: 0.00447876006365
# training eve, run: 1
# training loss: 1.00009763241
# training loss: 0.271720826626
# training loss: 0.0344744250178
# training loss: 0.0157273951918
# training loss: 0.0109080467373
# training loss: 0.00967598706484
# training bob and alice, run: 2
# training loss: 0.984929859638
# training loss: 0.133954614401
# training loss: 0.129056617618
# training loss: 0.127151027322
# training loss: 0.121068775654
# training loss: 0.125507384539
# ...

# %%
# batch_size = 512
# msg_len = 16 bits
# key_len = 16 bits
# comm_len = 16 bits

# No.of Adversarial runs = 60
# No. of iterations in each run = 2000
# Learning rate = 0.0001

# %run adversarial_neural_cryptography.py
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5105)
# /home/icarus/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# training bob and alice, run: 1
# training loss: 0.998113751411
# training loss: 0.998477697372
# training loss: 0.997463822365
# training loss: 0.981605529785
# training loss: 0.925810694695
# training loss: 0.829382896423
# training loss: 0.699284732342
# training loss: 0.586750328541
# training loss: 0.510953366756
# training loss: 0.430951923132
# training eve, run: 1
# training loss: 0.999871611595
# training loss: 0.996484339237
# training loss: 0.977694272995
# training loss: 0.94643163681
# training loss: 0.89418900013
# training loss: 0.823467433453
# training loss: 0.736380457878
# ...

# %% [markdown]
# <br/>Experiments with batch size of 256 and 1024

# %%
# batch_size = 256
# msg_len = 16 bits
# key_len = 16 bits
# comm_len = 16 bits

# No.of Adversarial runs = 60
# No. of iterations in each run = 2000
# Learning rate = 0.0001

# %run adversarial_neural_cryptography.py
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5105)
# /home/icarus/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# training bob and alice, run: 1
# training loss: 0.999251723289
# training loss: 0.999624252319
# training loss: 0.998278975487
# training loss: 0.990790009499
# training loss: 0.958557903767
# training loss: 0.896927118301
# training loss: 0.782609403133
# training loss: 0.688804924488
# training loss: 0.591628432274
# training loss: 0.51683139801
# training eve, run: 1
# training loss: 0.999865531921
# training loss: 0.996310353279
# training loss: 0.982847690582
# training loss: 0.952223062515
# training loss: 0.910835385323
# training loss: 0.843388557434
# training loss: 0.776961266994
# ...

# %%
# batch_size = 1024
# msg_len = 16 bits
# key_len = 16 bits
# comm_len = 16 bits


# No.of Adversarial runs = 60
# No. of iterations in each run = 2000
# Learning rate = 0.0001

# %run adversarial_neural_cryptography.py
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5105)
# /home/icarus/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# training bob and alice, run: 1
# training loss: 0.99950838089
# training loss: 0.999813199043
# training loss: 0.996013343334
# training loss: 0.963384985924
# training loss: 0.885548889637
# training loss: 0.755262374878
# training loss: 0.624357283115
# training loss: 0.526912093163
# training loss: 0.444562196732
# training loss: 0.378167331219
# training eve, run: 1
# training loss: 0.999945640564
# training loss: 0.995418608189
# training loss: 0.974572896957
# training loss: 0.936761558056
# training loss: 0.879687428474
# training loss: 0.798315048218
# training loss: 0.708270668983
# ...

# %%
# Using SGD acceleration
# batch_size = 512
# msg_len = 16 bits
# key_len = 16 bits
# comm_len = 16 bits

# No.of Adversarial runs = 60
# No. of iterations in each run = 2000
# Learning rate = 0.0001

# %run adversarial_neural_cryptography.py
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5105)
# /home/icarus/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# training bob and alice, run: 1
# training loss: 0.999598026276
# training loss: 0.997961521149
# training loss: 0.998485863209
# training loss: 0.998411238194
# training loss: 1.00102484226
# training loss: 1.0023393631
# training loss: 0.997808933258
# training loss: 1.00114965439
# training loss: 1.00152778625
# training loss: 0.999603450298
# training eve, run: 1
# training loss: 0.999938070774
# training loss: 0.999963998795
# training loss: 0.999981760979
# training loss: 0.999983489513
# training loss: 0.999967396259
# training loss: 0.999957680702
# training loss: 0.999978303909
# training loss: 0.999945580959
# ...

# %%
# batch_size = 512
# msg_len = 16 bits
# key_len = 16 bits
# comm_len = 16 bits

# No.of Adversarial runs = 60
# No. of iterations in each run = 2000
# Learning rate = 0.01

# %run adversarial_neural_cryptography.py
# Out:
# training bob and alice, run: 1
# training loss: 1.00055480003
# training loss: 0.0013807984069
# training eve, run: 1
# training loss: 1.00010836124
# training bob and alice, run: 2
# training loss: 0.992906332016
# training loss: 0.00742641603574
# training eve, run: 2
# training loss: 0.955820143223
# training loss: 0.0320551022887
# training loss: 0.0305081475526
# training loss: 0.0367269068956
# training loss: 0.0308345295489
# training loss: 0.0308277904987
# training loss: 0.0292171426117
# training loss: 0.0373350344598
# training loss: 0.0345156155527
# training loss: 0.0287865009159
# training bob and alice, run: 3
# training loss: 0.936665475368
# training loss: 0.252377927303
# training loss: 0.25304415822
# training loss: 0.257996320724
# training loss: 0.250464588404
# training loss: 0.194049417973
# training loss: 0.18405804038
# training loss: 0.133558645844
# training loss: 0.124528102577
# training loss: 0.130458638072
# training eve, run: 3
# ...

# %%
# batch_size = 512
# msg_len = 32 bits
# key_len = 32 bits
# comm_len = 32 bits

# No.of Adversarial runs = 60
# No. of iterations in each run = 2000
# Learning rate = 0.001

# %run adversarial_neural_cryptography.py
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5105)
# /home/icarus/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# training bob and alice, run: 1
# training loss: 1.0002720356
# training loss: 0.305463373661
# training loss: 0.0230454150587
# training loss: 0.00499415118247
# training eve, run: 1
# training loss: 1.00011396408
# training loss: 0.204376935959
# training loss: 0.0210714973509
# training loss: 0.0094257267192
# training bob and alice, run: 2
# training loss: 0.987865686417
# training loss: 0.0105109419674
# training eve, run: 2
# training loss: 0.96692276001
# training loss: 0.114937290549
# training loss: 0.0719762593508
# training loss: 0.0532922968268
# training loss: 0.0329307019711
# ...

# %%
# batch_size = 1024
# msg_len = 32 bits
# key_len = 32 bits
# comm_len = 32 bits

# No.of Adversarial runs = 60
# No. of iterations in each run = 2000
# Learning rate = 0.001

# %run adversarial_neural_cryptography.py
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5105)
# /home/icarus/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# training bob and alice, run: 1
# training loss: 1.00026130676
# training loss: 0.239427998662
# training loss: 0.0160032752901
# training eve, run: 1
# training loss: 1.00003480911
# training loss: 0.254325479269
# training loss: 0.0949338078499
# training loss: 0.038536451757
# training loss: 0.0253693740815
# training loss: 0.0218635573983
# training loss: 0.00474452227354
# training bob and alice, run: 2
# training loss: 0.99723470211
# training loss: 0.00646953005344
# training eve, run: 2
# training loss: 0.982100367546
# training loss: 0.0389445461333
# training loss: 0.0363389104605
# ...
